# %% [markdown]
# **A932 - სტატისტიკა**
# <br>
# თარიღი: **10 დეკემბერი 2020**
# <br>
#
# სათაური: **საშინაო დავალება 2**
# <br>
# მომხსენებელი: **შოთა ცისკარიძე**
# <br>
#
# ჩაბარების ბოლო ვადა: **31 დეკემბერი 18:00**.
#
#
# დავალება შედგება **10 ამოცანისგან**.
# <br>
# თითოეული ამოცანა ფასდება **1 ქულით**.

# %% [markdown]
# <h3 align="center">ამოცანა №1: ბინომიალური განაწილება</h3>
#
#
# მოცემულია $X$ **დისკრეტული** შემთხვევითი სიდიდე **ბინომიალური ალბათური განაწილებით**.
#
# ცნობილია, რომ $X$-ის **ვარიაცია** $100$-ს დამოუკიდებელ **ცდაში** $21$-ის ტოლია.
#
# რისი ტოლია **წარმატების ალბათობა** თითოეულ ცდაში?

# %% [markdown]
# <h3 align="center">ამოცანა №2: მულტინომიალური განაწილება</h3>
#
# ქვევით მოცემულია ცხრილი თუ ავსტრიის მოსახლეობის რა პროცენტი ფლობს ამა თუ იმ ჯგუფის სისხლს:
#
# | სისხლის ჯგუფი | მოსახლეობის $\%$ |
# |:-------------:|:----------------:|
# |      $O+$     |      $30$      |
# |      $A+$     |      $33$      |
# |      $B+$     |      $12$      |
# |     $AB+$     |       $6$      |
# |      $O-$     |       $7$      |
# |      $A-$     |       $8$      |
# |      $B-$     |       $3$      |
# |     $AB-$     |       $1$      |
#
#
# თუ ავსტრიის $15$ მოქალაქეს შემთხვევითად ავირჩევთ, რა არის იმის ალბათობა, რომ:
#
# - $3$-ს აქვს $O+$ ჯგუფის სისხლი,
# - $2$-ს აქვს $A+$ ჯგუფის სისხლი,
# - $3$-ს აქვს $B+$ ჯგუფის სისხლი,
# - $2$-ს აქვს $AB+$ ჯგუფის სისხლი,
# - $1$-ს აქვს $O-$ ჯგუფის სისხლი,
# - $2$-ს აქვს $A-$ ჯგუფის სისხლი,
# - $1$-ს აქვს $B-$ ჯგუფის სისხლი,
# - $1$-ს აქვს $AB-$ ჯგუფის სისხლი?

# %% [markdown]
# <h3 align="center">ამოცანა №3: ჰიპერგეომეტრიული განაწილება (კავშირი ბინომიალურ განაწილებასთან)</h3>
#
# ცნობილია, რომ $10000$ ამომრჩეველიდან $4000$ გაყიდვებზე ახალი გადასახადის შემოტანის წინააღმდეგია.
#
# თუ შემთხვევითად გამოვკითხავთ $15$ ამომრჩეველს, რა ალბათობაა, რომ მაქსიმუმ $7$-ი ამომრჩეველი ემხრობა ახალ გადასახადს?

# %% [markdown]
# <h3 align="center">ამოცანა №4: უარყოფითი ბინომიალური განაწილება</h3>
#
# **ალბათობა** იმისა, რომ გარკვეულ ქალაქში მცხოვრები ადამიანს ჰყავს ძაღლი, შეფასებულია $0.3$-ით.
#
# **იპოვნეთ ალბათობა**, რომ ამ ქალაქში შემთხვევით გამოკითხული **მეათე** ადამიანი **მეხუთეა**, ვინც ჰყავს ძაღლი.

# %% [markdown]
# <h3 align="center">ამოცანა №5: გეომეტრიული განაწილება</h3>
#
#
# **ალბათობა** იმისა, რომ სტუდენტი ჩააბარებს გამოცდას $0.7$-ის ტოლია.
#
# რა არის იმის **ალბათობა**, რომ მოცემული სტუდენტი ჩააბარებს გაცმოდას:
#
# ა) **მესამე ცდაზე**.
#
# ბ) **მეოთხე ცდამდე**.

# %% [markdown]
# <h3 align="center">ამოცანა №6: ბინომიალური განაწილების მიახლოება პუასონის განაწილებით</h3>
#
#  გარკვეულ სამშენებლო ობიექტზე უბედური შემთხვევბი **იშვიათად ხდება**.
#
#   ცნობილია, რომ **უბედური შემთხვევის ალბათობაა** $0.001$ და უბედური შემთხვევები **ერთმანეთისგან დამოუკიდებელია**.
#
#   ა) რა არის იმის **ალბათობა**, რომ მოცემული **წლის** ერთ დღესაც **მოხდება უბედური შემთხვევა**?
#
#   ბ) რა არის იმის **ალბათობა**, რომ უბედური შემთხვევების რაოდენობა **არ აღემატებოდეს** $3$-ს?

# %% [markdown]
# <h3 align="center">ამოცანა №7: თანაბარი განაწილება</h3>
#
# ავტობუსი მოდის გაჩერებაზე ყოველ $10$ წუთში ერთხელ.
#
# ივარაუდება, რომ კონკრეტული ადამიანის ლოდინის დრო არის შემთხვევითი სიდიდე **უწყვეტი თანაბარი განაწილებით**.
#
# ა) რა არის იმის **ალბათობა**, რომ ადამიანი $7$ წუთზე მეტს ელოდება ავტობუსს?
#
# ბ) რა არის იმის **ალბათობა**, რომ ადამიანი ელოდება ავტობუსს $2$–დან $7$ წუთამდე?

# %% [markdown]
# <h3 align="center">ამოცანა №8: ნორმალური განაწილება</h3>
#
# $1000$ სტუდენტის სიმაღლე **ნორმალურად** არის განაწილებული **საშუალო** მინშვნელობით $174.5$ სანტიმეტრი და **სტანდარტული გადახრით** $6.9$ სანტიმეტრი.
#
# თუ სიმაღლე გამოითვლება უახლოეს ნახევარ სანტიმეტრამდე, დათვალეთ იმის **მოლოდინი**, რომ სტუდენტის სიმაღლეს ექნება:
#
# ა) $160.0$ სანტიმეტრზე ნაკლები?
#
# ბ) $171.5$ და $182.0$ სანტიმეტრს შორის?
#
# გ) ზუსტად $175.0$ სანტიმეტრის ტოლი?
#
# დ) $188.0$ სანტიმეტზე მეტი ან ტოლი?

# %% [markdown]
# <h3 align="center">ამოცანა №9: ნორმალური განაწილება (უკუგამოთვლა)</h3>
#
#   მოცემულია $X$ **ნორმალურად განაწილებული** შემთხვევითი სიდიდე **ლოდინით** $\mu = 36$ და **ვარიაციით** $\sigma = 6$.
#
#   იპოვნეთ $X$-ის მნიშვნელობა, რომლისთვისაც:
#
#   ა) **მარცხნივ** მდებარე ფართობი შეადგენდეს $40\%$
#
#   ბ) **მარჯვნივ** მდებარე ფართობი შეადგენდეს $17\%$

# %% [markdown]
# <h3 align="center">ამოცანა №10: გამა ფუნქცია</h3>
#
# გამოთვალეთ შემდეგი გამოსახულება:
#
# $$\frac{\Gamma \left ( \frac{16}{5}\right ) }{\Gamma \left ( \frac{1}{5}\right )},$$
#
# სადაც $\Gamma( \cdot )$ არის გამა ფუნქცია.

# %% [markdown]
# <h1 align="center">გისურვებთ წარმატებას!</h2>

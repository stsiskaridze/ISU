# %% [markdown]
# **R527 - დაპროგრამება პითონში**
# <br>
# თარიღი: **20 ნოემბერი 2020**
# <br>
#
# სათაური: **სავარჯიშო 37**
# <br>
# მომხსენებელი: **შოთა ცისკარიძე**
#
#
# ბიბლიოგრაფია:
# <br>
#  **სავარჯიშო 37.** Zed Shaw, *Learn Python 3 the Hard Way*, Addison Wesley (Verlag), 2017

# %% [markdown]
# <h1 align="center">სავარჯიშო 37: სიმბოლოები და საკვანძო სიტყვები </h1>

# %% [markdown]
# <center><img src="images/Ex_37_Intro.png" width="500"alt="Example" /></center>

# %% [markdown]
# - ამ სავარჯიშოში ამოკრეფილია **Python**-ისთვის მნიშვნელოვანი **სიმბოლოები** და **საკვანძო სიტყვები**.
#
#
# - შეეცადეთ ჯერ გაიხსენოთ, რას ნიშნავს ესა თუ ის სიმბოლო, შემდეგ გადაამოწმეთ ამ სავარჯიშოში მოცემულ ცხრილებსა.
#
#
# - და ბოლოს, შეეცადეთ თითოეული მათგანი გამოიყენოს **Python**-ის პატარა პროგრამის დაწერაში, რათა უფრო დაგამახრსოვდეთ.
#
#
# - ამ სავარჯიშოს მიზანია გავიგოთ და დავიმახსოვროთ, თუ რას აკეთებს კონკრეტული სიმბოლო და სიტყვა.

# %% [markdown]
# <h2 align="center">საკვანძო სიტყვები </h2>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">სიტყვა</th>
#     <th class="tg-0lax">აღწერა</th>
#     <th class="tg-0lax">მაგალითი</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">and</td>
#     <td class="tg-0lax">ლოგიკური ოპერაცია $\textbf{და}$</td>
#     <td class="tg-0lax">True and False == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">as</td>
#     <td class="tg-0lax">$\textbf{with as}$ დებულების ნაწილი</td>
#     <td class="tg-0lax">with X as Y: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">assert</td>
#     <td class="tg-0lax">პირობის შემოწმება და არშესრულების შემთხვევაში შეცდომის გამოტანა</td>
#     <td class="tg-0lax">assert False, "Error!"</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">break</td>
#     <td class="tg-0lax">ციკლის გაჩერება და გამოსვლა</td>
#     <td class="tg-0lax">while True: break</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">class</td>
#     <td class="tg-0lax">კლასის განსაზღვრა</td>
#     <td class="tg-0lax">class Person(object)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">continue</td>
#     <td class="tg-0lax">ციკლის იტერაციის გამოტოვება</td>
#     <td class="tg-0lax">while True: continue</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">def</td>
#     <td class="tg-0lax">ფუნქციის განსაზღვრა</td>
#     <td class="tg-0lax">def X(): pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">del</td>
#     <td class="tg-0lax">ლექსიკონიდან წაშლა</td>
#     <td class="tg-0lax">del X[Y]</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">elif</td>
#     <td class="tg-0lax">$\textbf{else if}$ პირობა</td>
#     <td class="tg-0lax">if: X; elif: Y; else: J</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">else</td>
#     <td class="tg-0lax">$\textbf{else}$ პირობა</td>
#     <td class="tg-0lax">if: X; elif: Y; else: J</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">except</td>
#     <td class="tg-0lax">თუ გამონაკლისი მოხდება, გააკეთე ეს</td>
#     <td class="tg-0lax">except ValueError: e: print(e)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">exec</td>
#     <td class="tg-0lax">ეს სტრიქონი გაუშვი, როგორ Python</td>
#     <td class="tg-0lax">exec 'print("hello")'</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">finally</td>
#     <td class="tg-0lax">გამონაკლისი გვაქვს თუ არა, აუცილებლად შეასრულე ეს სულ-სულ ბოლოს</td>
#     <td class="tg-0lax">finally: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">for</td>
#     <td class="tg-0lax">ციკლი, როცა მოცემულია მნიშვნელობების კოლექცია</td>
#     <td class="tg-0lax">for X in Y: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">from</td>
#     <td class="tg-0lax">მოდულის მეთოდების იმპორტირება</td>
#     <td class="tg-0lax">from X import Y</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">global</td>
#     <td class="tg-0lax">გლობალური ცვლადი განსაზღვრა</td>
#     <td class="tg-0lax">global X</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">if</td>
#     <td class="tg-0lax">If პირობა</td>
#     <td class="tg-0lax">if: X; elif: Y; else: J</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">import</td>
#     <td class="tg-0lax">მოდულის იმპორტირება</td>
#     <td class="tg-0lax">import os</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">in</td>
#     <td class="tg-0lax">$\textbf{for}$-ციკლის ნაწილი. ასევე X in Y დებულების შემოწმება</td>
#     <td class="tg-0lax">for X in Y: pass also 1 in [1] == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">is</td>
#     <td class="tg-0lax">ანალოგიურია $\textbf{==}$, იდენტურობის შემოწმება</td>
#     <td class="tg-0lax">1 is 1 == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">lamba</td>
#     <td class="tg-0lax">უსახელო ფუნქციის შექმნა</td>
#     <td class="tg-0lax">s = lambda y: y ** y; s(3)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">not</td>
#     <td class="tg-0lax">ლოგიკური უარყოფის ოპერაცია $\textbf{not}$</td>
#     <td class="tg-0lax">not True == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">or</td>
#     <td class="tg-0lax">ლოგიკური ოპერაცია $\textbf{or}$</td>
#     <td class="tg-0lax">True or False == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">pass</td>
#     <td class="tg-0lax">ცარიელი ბლოკის განსაზღვრა</td>
#     <td class="tg-0lax">def empty(): pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">print</td>
#     <td class="tg-0lax">ამობეჭდვა</td>
#     <td class="tg-0lax">print('ეს სტრიქონი')</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">raise</td>
#     <td class="tg-0lax">გამონაკლისის შემოტანა, როცა კოდი არასწორად იმუშავებს</td>
#     <td class="tg-0lax">raise ValueError("No")</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">return</td>
#     <td class="tg-0lax">ფუნქციის შედეგის გამოტანა</td>
#     <td class="tg-0lax">def X(): return Y</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">try</td>
#     <td class="tg-0lax">გამოსცადე ეს ბლოკი და თუ ის გამონაკლასია, გადადი გამონაკლისზე (except)</td>
#     <td class="tg-0lax">try: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">while</td>
#     <td class="tg-0lax">$\textbf{while}$ ციკლი</td>
#     <td class="tg-0lax">while X: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">with</td>
#     <td class="tg-0lax">თუ ცვლადი გამონაკლისია, შეასრულე ეს</td>
#     <td class="tg-0lax">with X as Y: pass</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">yield</td>
#     <td class="tg-0lax">გაჭერი აქ და დაუბრუნდი გამომძახებელს</td>
#     <td class="tg-0lax">def X(): yield Y; X().next()</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <h2 align="center"> მონაცემის ტიპები </h2>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">ტიპი</th>
#     <th class="tg-0lax">აღწერა</th>
#     <th class="tg-0lax">მაგალითი</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">True</td>
#     <td class="tg-0lax">ბულიანის მართალი მნიშვნელობა</td>
#     <td class="tg-0lax">True or False == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">False</td>
#     <td class="tg-0lax">ბულიანის მცდარი მნიშვნელობა</td>
#     <td class="tg-0lax">False and True == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">None</td>
#     <td class="tg-0lax">წარმოადგენს "არაფერს" ან "მნიშვნელობის გარეშე"</td>
#     <td class="tg-0lax">x = None</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">bytes</td>
#     <td class="tg-0lax">ინახავს ბაიტებს</td>
#     <td class="tg-0lax">x = b"hello"</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">strings</td>
#     <td class="tg-0lax">ინახავს ტექსტურ ინფორმაციას</td>
#     <td class="tg-0lax">x = "hello"</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">int</td>
#     <td class="tg-0lax">ინახავს მთელ რიცხვებს</td>
#     <td class="tg-0lax">i = 100</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">floats</td>
#     <td class="tg-0lax">ინახავს ათწილადებს</td>
#     <td class="tg-0lax">i = 10.389</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">lists</td>
#     <td class="tg-0lax">ინახავს მნიშვნელობების სიას</td>
#     <td class="tg-0lax">j = [1, 2, 3, 4]</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">dicts</td>
#     <td class="tg-0lax">ინახავს რუკას სახელი=მნიშვნელობა</td>
#     <td class="tg-0lax">e = {'x' : 1, 'y': 2}</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <h2 align="center"> სტრიქონიდან თავის დაღწევის საშუალება (Escape)</h2>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">ესკეიპის საშუალება</th>
#     <th class="tg-0lax">აღწერა</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">\\</td>
#     <td class="tg-0lax">ერთი დახრილი ხაზი</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\'</td>
#     <td class="tg-0lax">ცალი ბრჭყალი</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\"</td>
#     <td class="tg-0lax">ორმაგი ბრჭყალი</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\a</td>
#     <td class="tg-0lax">ზარი (Bell)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\b</td>
#     <td class="tg-0lax">ერთით წაშლა (backspace)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\f</td>
#     <td class="tg-0lax">ფორმის მიცემა (Formfeed)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\n</td>
#     <td class="tg-0lax">ახალი ხაზი (Newline)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\r</td>
#     <td class="tg-0lax">გადაზიდვა (Carriage)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\t</td>
#     <td class="tg-0lax">გვერდი (Tab)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">\v</td>
#     <td class="tg-0lax">ვერტიკალური გვერდი (Vertical Tab)</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <h2 align="center"> ოპერატორები </h2>
#
# ზოგი ოპერატორი შეიძლება არ გეცნოთ, მეტი ინფორმაციისთვის მიმართეთ ინტერნეტ=წყაროებს.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">ოპერატორი</th>
#     <th class="tg-0lax">აღწერა</th>
#     <th class="tg-0lax">მაგალითი</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">+</td>
#     <td class="tg-0lax">დამატება</td>
#     <td class="tg-0lax">2 + 4 == 6</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">-</td>
#     <td class="tg-0lax">გამოკლება</td>
#     <td class="tg-0lax">2 - 4 == -2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">*</td>
#     <td class="tg-0lax">გამრავლება</td>
#     <td class="tg-0lax">2 * 4 == 8</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">**</td>
#     <td class="tg-0lax">ხარისხში აყვანა</td>
#     <td class="tg-0lax">2 ** 4 == 16</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">/</td>
#     <td class="tg-0lax">გაყოფა</td>
#     <td class="tg-0lax">2 / 4 = 0.5</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">//</td>
#     <td class="tg-0lax">იძლევა მთელ რიცხვს, რომელიც ნაკლებია ან უდრის გაყოფის შედეგის</td>
#     <td class="tg-0lax">2 // 4 == 0</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">%</td>
#     <td class="tg-0lax">სტრიქონის ჩასმა ან მოდული</td>
#     <td class="tg-0lax">2 % 4 == 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">&lt;</td>
#     <td class="tg-0lax">ნაკლებია </td>
#     <td class="tg-0lax">4 &lt; 4 == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">&gt; </td>
#     <td class="tg-0lax">მეტია</td>
#     <td class="tg-0lax">4 &gt; 4 == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">&lt;= </td>
#     <td class="tg-0lax">ნაკლებია ან უდრის</td>
#     <td class="tg-0lax">4 &lt;= 4 == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">&gt;=</td>
#     <td class="tg-0lax">მეტია ან უდრის </td>
#     <td class="tg-0lax">4 &gt;= 4 == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">==</td>
#     <td class="tg-0lax">უდრის</td>
#     <td class="tg-0lax">4 == 5 == False</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">!=</td>
#     <td class="tg-0lax">არ უდრის</td>
#     <td class="tg-0lax">4 !=5 == True</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">( )</td>
#     <td class="tg-0lax">მრგვალი ფრჩხილები</td>
#     <td class="tg-0lax">len('hi') == 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">[ ] </td>
#     <td class="tg-0lax">კვადრატული ფრჩხილები</td>
#     <td class="tg-0lax">[1, 2, 3]</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">{ }</td>
#     <td class="tg-0lax">ფიგურული ფრჩხილები</td>
#     <td class="tg-0lax">{'x': 2, 'y': 4, 'z': 7}</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">@</td>
#     <td class="tg-0lax">ამ (მეთოდით)</td>
#     <td class="tg-0lax">@classmethod</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">,</td>
#     <td class="tg-0lax">მძიმე</td>
#     <td class="tg-0lax">range(0, 10)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">:</td>
#     <td class="tg-0lax">ორიწერტილი</td>
#     <td class="tg-0lax">def X():</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">.</td>
#     <td class="tg-0lax">წერტილი</td>
#     <td class="tg-0lax">self.x = 10</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">=</td>
#     <td class="tg-0lax">მიანიჭე ტოლობა</td>
#     <td class="tg-0lax">x = 10</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">;</td>
#     <td class="tg-0lax">წერტილმძიმე</td>
#     <td class="tg-0lax">print('hi'); print('there')</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">+=</td>
#     <td class="tg-0lax">დაამატე და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x += 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">-=</td>
#     <td class="tg-0lax">გამოაკელი და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x -= 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">*=</td>
#     <td class="tg-0lax">გაამრავლე და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x *= 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">/=</td>
#     <td class="tg-0lax">გაყავი და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x /= 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">//=</td>
#     <td class="tg-0lax">გაყავი მთელ რიცხვად ნაკლებისკენ და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x //= 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">%=</td>
#     <td class="tg-0lax">მიანიჭე მოდული</td>
#     <td class="tg-0lax">x = 1; x %= 2</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">**=</td>
#     <td class="tg-0lax">აიყვანე ხარისხში და მიანიჭე</td>
#     <td class="tg-0lax">x = 1; x **= 2</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <h2 align="center"> კოდის კითხვა </h2>
#
# - ახლა კი მოძებნეთ რამე Python-ის კოდი და წაიკითხეთ ის. ამ ეტაპზე თქვენ უკვე გესმის ბევრი რამ, მეტი უნდა იკითხოთ და მოძებნოთ სასარგებლო იდეები.
#
# - პირველ რიგში, ამობეჭდეთ კოდი. დიახ, ამობეჭდვა უკეთესია, რადგან ჩვენი თვალები ფურცლიდან კითხვას მეტად შეჩვეულია.
#
# - მეორე, გადახედეთ კოდს და გააკეთეთ რემარკები შემდეგ საკითხებზე:
#
#   1. ფუნქციები, და რას ემსახურებია ისინი.
#
#   2. სად არის პირველად განსაზღვრული თითო ცვლადი.
#
#   3. იპოვეთ ცვლადები ერთნაირი სახელებით კოდის სხვადასხვა ნაწილში.
#
#   4. არის თუ არა რომელიმე `if` დებულება `else` პირობის გარეშე? სწორად იმუშავებს კოდი?
#
#   5. `while` ციკლი, რომელიც შეიძლება არასოდეს შეწყდეს?
#
#   6. კოდის ნაწილი, რომელიც არ გესმის სხვადასხვა მიზეზის გამო.
#
#
# - მესამე, ამ შენიშვნებს რომ მორჩებით, შეეცადეს თქვენ თავს აუხსნათ ისინი, თან მიაწერეთ კომენტარები. ახსენით ფუნქციები და როგორ მუშაობს ისინი, როგორ გამოიყენება, რა ცვლადებია ჩართული მასში და ა.შ.
#
# - და ბოლოს, სკრიპტის რთულ ნაწილს რაც შეეხება, შეეცადეთ თვალი ადევნოთ მის მუშაობას ხაზების გასწვრივ.

# %% [markdown]
# <h2 align="center">ხშირად დასმული კითხვები</h2>
#
# - ქვევით მოყვანილია კითხვები, რომლებიც გაუჩნდათ რეალურ სტუდენტებს ამ სავარჯიშოს შესრულებისას:
#
#
# 1. **როგორ მივმართო ინტერნეტ-წყაროებს?**
#
#     აკრიფეთ Python 3.8 და მიაწერეთ, თუ რას ეძებთ კონკრეტულად. მაგალითად, "Python 3.8 escape strings".

# %% [markdown]
# <h2 align="center">საშინაო დავალება</h2>
#
#
# 1. გაარკვიეთ, რას ნიშნავს "flow chart" და დახატეთ რამდენიმე.
#
# 2. თუ იპოვით შეცდომას იმ კოდში, რომელსაც კითხულობთ, შეასწორეთ და გაუგზავნეთ ამ კოდის ავტორს.
#
# 3. კიდევ ერთი ტექნიკა: თუ ფურცელს არ იყენებთ, მიაწერეთ თქვენს სკრიპტს კომენტარები.

# %% [markdown]
# <h1 align="center">სავარჯიშოს დასასრული</h1>
